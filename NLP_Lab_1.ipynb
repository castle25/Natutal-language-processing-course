# %%
import nltk

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
file16 = nltk.corpus.gutenberg.fileids( )[16]

# %%
file16
# Out:
# 'shakespeare-macbeth.txt'

# %%
emmatext = nltk.corpus.gutenberg.raw(file16)

# %%
print(emmatext[:250])
# Out:
# [The Tragedie of Macbeth by William Shakespeare 1603]
#
#
# Actus Primus. Scoena Prima.
#
# Thunder and Lightning. Enter three Witches.
#
#   1. When shall we three meet againe?
# In Thunder, Lightning, or in Raine?
#   2. When the Hurley-burley's done,
# When the B

# %%
len(emmatext)
# Out:
# 100351

# %%
nltk.download('punkt')
emmatokens = nltk.word_tokenize(emmatext)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
print(emmatokens)
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', 'William', 'Shakespeare', '1603', ']', 'Actus', 'Primus', '.', 'Scoena', 'Prima', '.', 'Thunder', 'and', 'Lightning', '.', 'Enter', 'three', 'Witches', '.', '1', '.', 'When', 'shall', 'we', 'three', 'meet', 'againe', '?', 'In', 'Thunder', ',', 'Lightning', ',', 'or', 'in', 'Raine', '?', '2', '.', 'When', 'the', 'Hurley-burley', "'s", 'done', ',', 'When', 'the', 'Battaile', "'s", 'lost', ',', 'and', 'wonne', '3', '.', 'That', 'will', 'be', 'ere', 'the', 'set', 'of', 'Sunne', '1', '.', 'Where', 'the', 'place', '?', '2', '.', 'Vpon', 'the', 'Heath', '3', '.', 'There', 'to', 'meet', 'with', 'Macbeth', '1', '.', 'I', 'come', ',', 'Gray-Malkin', 'All', '.', 'Padock', 'calls', 'anon', ':', 'faire', 'is', 'foule', ',', 'and', 'foule', 'is', 'faire', ',', 'Houer', 'through', 'the', 'fogge', 'and', 'filthie', 'ayre', '.', 'Exeunt', '.', 'Scena', 'Secunda', '.', 'Alarum', 'within', '.', 'Enter', 'King', 'Malcome', ',', 'Donalbaine', ',', 'Lenox', 
# ...

# %%
len(emmatokens)
# Out:
# 22211

# %%
emmawords = [w.lower( ) for w in emmatokens]

# %%
print(emmawords)
# Out:
# ['[', 'the', 'tragedie', 'of', 'macbeth', 'by', 'william', 'shakespeare', '1603', ']', 'actus', 'primus', '.', 'scoena', 'prima', '.', 'thunder', 'and', 'lightning', '.', 'enter', 'three', 'witches', '.', '1', '.', 'when', 'shall', 'we', 'three', 'meet', 'againe', '?', 'in', 'thunder', ',', 'lightning', ',', 'or', 'in', 'raine', '?', '2', '.', 'when', 'the', 'hurley-burley', "'s", 'done', ',', 'when', 'the', 'battaile', "'s", 'lost', ',', 'and', 'wonne', '3', '.', 'that', 'will', 'be', 'ere', 'the', 'set', 'of', 'sunne', '1', '.', 'where', 'the', 'place', '?', '2', '.', 'vpon', 'the', 'heath', '3', '.', 'there', 'to', 'meet', 'with', 'macbeth', '1', '.', 'i', 'come', ',', 'gray-malkin', 'all', '.', 'padock', 'calls', 'anon', ':', 'faire', 'is', 'foule', ',', 'and', 'foule', 'is', 'faire', ',', 'houer', 'through', 'the', 'fogge', 'and', 'filthie', 'ayre', '.', 'exeunt', '.', 'scena', 'secunda', '.', 'alarum', 'within', '.', 'enter', 'king', 'malcome', ',', 'donalbaine', ',', 'lenox', 
# ...

# %%
len(emmawords)
# Out:
# 22211

# %%
 emmavocab = sorted(set(emmawords))

# %%
print(emmavocab)
# Out:
# ['!', '&', "'", "'boue", "'d", "'em", "'faith", "'gainst", "'ginne", "'gins", "'re", "'s", "'t", "'tis", "'twer", "'twere", "'twixt", "'twould", '(', ')', ',', '-', '.', '1', '1.murth', '1603', '2', '2.murth', '3', '3.', ':', ';', '?', '[', ']', 'a', 'a-foot', 'a-weary', 'abhorred', 'abide', 'abiure', 'aboue', 'abound', 'about', 'abroad', 'absence', 'absent', 'absolute', 'abuse', 'accents', 'accesse', 'accompany', 'accompt', 'according', 'account', 'accounted', "accurs'd", 'accursed', 'accust', 'accustom', 'acheron', 'acquaint', 'act', 'acted', 'acting', 'action', 'actions', 'acts', 'actuall', 'actus', 'addage', 'adde', 'added', 'adders', 'addition', 'addrest', 'adhere', 'adieu', 'admir', 'aduance', 'aduantage', 'aduice', 'aduise', 'afeard', 'affaire', 'affaires', 'affear', "affear'd", 'affection', 'affliction', 'affraid', 'afraid', 'after', 'afternoone', 'afterwards', 'againe', 'against', 'age', 'agent', 'agents', 'agitation', 'ague', 'aid', 'alack', 'alarme', 'alarum', 'alarums', '
# ...

# %%
from nltk import FreqDist

# %%
fdist = FreqDist(emmawords)
fdistkeys = list(fdist.keys())

# %%
fdistkeys[:30]
# Out:
# ['[',
#  'the',
#  'tragedie',
#  'of',
#  'macbeth',
#  'by',
#  'william',
#  'shakespeare',
#  '1603',
#  ']',
#  'actus',
#  'primus',
#  '.',
#  'scoena',
#  'prima',
#  'thunder',
#  'and',
#  'lightning',
#  'enter',
#  'three',
#  'witches',
#  '1',
#  'when',
#  'shall',
#  'we',
#  'meet',
#  'againe',
#  '?',
#  'in',
#  ',']

# %%
topkeys = fdist.most_common(30)

# %%
for pair in topkeys:
    print(pair)
# Out:
# (',', 1962)
# ('.', 1219)
# ('the', 649)
# ('and', 545)
# (':', 477)
# ('to', 383)
# ('of', 338)
# ('i', 331)
# ('?', 241)
# ('a', 239)
# ('that', 236)
# ('is', 211)
# ('my', 203)
# ('you', 203)
# ('in', 200)
# ("'d", 192)
# ('not', 185)
# ('it', 161)
# ('with', 153)
# ('his', 146)
# ('be', 137)
# ('macb', 137)
# ("'s", 128)
# ('your', 126)
# ('our', 123)
# ('haue', 122)
# ('but', 120)
# ('what', 117)
# ('me', 113)
# ('he', 112)

# %%
numwords = len(emmawords)

# %%
topkeysnormalized = [(word, freq / numwords) for (word, freq) in topkeys]

# %%
for pair in topkeysnormalized:
          print(pair)
# Out:
# (',', 0.08833460897753366)
# ('.', 0.05488271577146459)
# ('the', 0.029219755976768267)
# ('and', 0.024537391382648238)
# (':', 0.021475845301877447)
# ('to', 0.01724370807257665)
# ('of', 0.0152176849308901)
# ('i', 0.014902525775516635)
# ('?', 0.010850479492143532)
# ('a', 0.010760434019179685)
# ('that', 0.010625365809733915)
# ('is', 0.009499797397685831)
# ('my', 0.009139615505830444)
# ('you', 0.009139615505830444)
# ('in', 0.009004547296384674)
# ("'d", 0.008644365404529288)
# ('not', 0.008329206249155823)
# ('it', 0.007248660573589662)
# ('with', 0.006888478681734276)
# ('his', 0.006573319526360812)
# ('be', 0.006168114898023502)
# ('macb', 0.006168114898023502)
# ("'s", 0.005762910269686191)
# ('your', 0.005672864796722345)
# ('our', 0.005537796587276575)
# ('haue', 0.005492773850794651)
# ('but', 0.005402728377830805)
# ('what', 0.005267660168385035)
# ('me', 0.005087569222457341)
# ('he', 0.005042546485975417)
